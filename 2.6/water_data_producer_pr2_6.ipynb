# %% [markdown]
# ## **Hasta Ejercicio 2.6**

# %%
from kafka import KafkaProducer
import json
import time
import random
from math import cos, pi
import numpy as np

# %%
def generate_sensor_data():
    timestamp = int(time.time())

    # Simulate IoT sensor data for water quality metrics with realistic patterns
    water_temperature = random.uniform(1, 3) + round(20 + 5 * (1 + 0.5 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi))), 2)
    ph_level = random.uniform(0, 1) + round(7.5 + 0.2 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi)), 2)
    turbidity = round(random.uniform(5, 50), 2)  # Turbidity in NTU (Nephelometric Turbidity Units)
    dissolved_oxygen = round(random.uniform(5, 12), 2)  # Dissolved Oxygen in mg/L
    
    return {
        "timestamp": timestamp,
        "water_temperature": water_temperature,
        "ph_level": ph_level,
        "turbidity": turbidity,
        "dissolved_oxygen": dissolved_oxygen
    }

# %%
import sys
import time
# Kafka configuration
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

producer_number = 3
producers = []
producer_ids = []

for i in range(producer_number):
    producer_ids.append(str(i))
    # Create Kafka producer
    producer = KafkaProducer(bootstrap_servers=kafka_bootstrap_servers,value_serializer=lambda v: json.dumps(v).encode('utf-8'))

    producers.append(producer)

print(f"Producing messages to Kafka topic '{kafka_topic}'...")

try:
    while True:
        for i in range(producer_number):
            # Generate sensor data
            sensor_data = generate_sensor_data()
            print(f'Productor: {i}')
            # Publish sensor data to Kafka
            producers[i].send(kafka_topic, key=producer_ids[i].encode('utf-8'),value=sensor_data)
            print(f"Sent: {sensor_data}")

        # Wait for 1 second
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped producing messages.")
finally:
    for producer in producers:
        producer.close()
# Out:
# Producing messages to Kafka topic 'water_quality'...
# Productor: 0
# Sent: {'timestamp': 1741174738, 'water_temperature': 26.76680042699825, 'ph_level': 7.917129207297975, 'turbidity': 29.63, 'dissolved_oxygen': 6.35}
# Productor: 1
# Sent: {'timestamp': 1741174738, 'water_temperature': 27.4938983241883, 'ph_level': 7.744088351841525, 'turbidity': 19.06, 'dissolved_oxygen': 8.56}
# Productor: 2
# Sent: {'timestamp': 1741174739, 'water_temperature': 26.35744692525732, 'ph_level': 7.853927959346652, 'turbidity': 13.21, 'dissolved_oxygen': 10.39}
# Productor: 0
# Sent: {'timestamp': 1741174740, 'water_temperature': 27.71728098358934, 'ph_level': 7.524504494228858, 'turbidity': 38.8, 'dissolved_oxygen': 10.37}
# Productor: 1
# Sent: {'timestamp': 1741174740, 'water_temperature': 26.764534648637614, 'ph_level': 8.167764383959064, 'turbidity': 35.17, 'dissolved_oxygen': 8.15}
# Productor: 2
# Sent: {'timestamp': 1741174740, 'water_temperature': 27.855342288764806, 'ph_level': 7.570903713470159, 'turbidity': 17.71, 'dissolved_oxygen': 8.57}
# Productor: 0
# Sent: {'timestamp': 1741174741, 'water_temperature': 27.508828197985846, 'ph_level': 7.626351698381415, 'turbidity': 8.4, 'dissolved_oxygen': 5.82}
# Productor: 1
# Sent: {'timestamp': 1741174741, 'water_temperature': 26.342629454850027, 'ph_level': 7.6951792424992105, 'turbidity': 10.76, 'dissolved_oxygen': 8.24}
# Productor: 2
# Sent: {'timestamp': 1741174741, 'water_temperature': 26.58300017127135, 'ph_level': 7.604008993620008, 'turbidity': 47.86, 'dissolved_oxygen': 5.15}
# Productor: 0
# Sent: {'timestamp': 1741174742, 'water_temperature': 26.37228508160638, 'ph_level': 7.819614968239022, 'turbidity': 7.22, 'dissolved_oxygen': 11.06}
# Productor: 1
# Sent: {'timestamp': 1741174742, 'water_temperature': 26.43394268784956, 'ph_level': 8.39089956882933, 'turbidity': 16.93, 'dissolved_oxygen': 11.18}
# Productor: 2
# Sent: {'timestamp': 1741174742, 'water_temperature': 26.91931792113773, 'ph_level': 8.044193711822993, 'turbidity': 37.56, 'dissolved_oxygen': 11.21}
# Productor: 0
# Sent: {'timestamp': 1741174743, 'water_temperature': 26.126535735247202, 'ph_level': 8.335905796283932, 'turbidity': 6.91, 'dissolved_oxygen': 8.89}
# Productor: 1
# Sent: {'timestamp': 1741174743, 'water_temperature': 27.719353935084158, 'ph_level': 8.227204404884153, 'turbidity': 12.6, 'dissolved_oxygen': 9.89}
# Productor: 2
# Sent: {'timestamp': 1741174743, 'water_temperature': 27.251153951914286, 'ph_level': 7.975461219636557, 'turbidity': 47.95, 'dissolved_oxygen': 6.35}
# Productor: 0
# Sent: {'timestamp': 1741174744, 'water_temperature': 26.128088269553412, 'ph_level': 8.187597466366938, 'turbidity': 31.65, 'dissolved_oxygen': 5.32}
# Productor: 1
# Sent: {'timestamp': 1741174744, 'water_temperature': 27.700218260975603, 'ph_level': 8.401085213719844, 'turbidity': 33.76, 'dissolved_oxygen': 6.39}
# Productor: 2
# Sent: {'timestamp': 1741174744, 'water_temperature': 27.059665279402097, 'ph_level': 8.434011565444928, 'turbidity': 16.32, 'dissolved_oxygen': 11.78}
# Productor: 0
# Sent: {'timestamp': 1741174745, 'water_temperature': 27.68720589128857, 'ph_level': 8.351673589047046, 'turbidity': 11.89, 'dissolved_oxygen': 5.02}
# Productor: 1
# Sent: {'timestamp': 1741174745, 'water_temperature': 26.64091986853792, 'ph_level': 7.534575538776638, 'turbidity': 38.2, 'dissolved_oxygen': 11.03}
# Productor: 2
# Sent: {'timestamp': 1741174745, 'water_temperature': 26.87458890044712, 'ph_level': 7.893653360153137, 'turbidity': 48.91, 'dissolved_oxygen': 10.19}
# Productor: 0
# Sent: {'timestamp': 1741174746, 'water_temperature': 27.4507839685239, 'ph_level': 8.412448097937501, 'turbidity': 28.93, 'dissolved_oxygen': 7.19}
# Productor: 1
# Sent: {'timestamp': 1741174746, 'water_temperature': 26.539072821560026, 'ph_level': 7.949755049726619, 'turbidity': 7.69, 'dissolved_oxygen': 6.85}
# Productor: 2
# Sent: {'timestamp': 1741174746, 'water_temperature': 27.670543725649146, 'ph_level': 7.921111920297853, 'turbidity': 19.08, 'dissolved_oxygen': 8.32}
# Productor: 0
# Sent: {'timestamp': 1741174747, 'water_temperature': 26.53521832450292, 'ph_level': 7.652433123818456, 'turbidity': 36.09, 'dissolved_oxygen': 7.85}
# Productor: 1
# Sent: {'timestamp': 1741174747, 'water_temperature': 26.769348078598476, 'ph_level': 7.650674243257014, 'turbidity': 21.23, 'dissolved_oxygen': 10.59}
# Productor: 2
# Sent: {'timestamp': 1741174747, 'water_temperature': 26.643407414238954, 'ph_level': 8.295971211861731, 'turbidity': 10.15, 'dissolved_oxygen': 10.01}
# Productor: 0
# Sent: {'timestamp': 1741174748, 'water_temperature': 26.714498120630996, 'ph_level': 8.313144959915949, 'turbidity': 36.4, 'dissolved_oxygen': 12.0}
# Productor: 1
# Sent: {'timestamp': 1741174748, 'water_temperature': 26.086600293411582, 'ph_level': 7.963289318609316, 'turbidity': 30.49, 'dissolved_oxygen': 5.49}
# Productor: 2
# Sent: {'timestamp': 1741174748, 'water_temperature': 27.514672709912862, 'ph_level': 8.188333238308177, 'turbidity': 20.55, 'dissolved_oxygen': 5.57}
# Productor: 0
# Sent: {'timestamp': 1741174749, 'water_temperature': 26.069363075737385, 'ph_level': 8.209927019326372, 'turbidity': 41.35, 'dissolved_oxygen': 7.29}
# Productor: 1
# Sent: {'timestamp': 1741174749, 'water_temperature': 26.885759543804102, 'ph_level': 7.990197043901838, 'turbidity': 28.01, 'dissolved_oxygen': 8.7}
# Productor: 2
# Sent: {'timestamp': 1741174749, 'water_temperature': 26.660777406332354, 'ph_level': 8.217846336273817, 'turbidity': 33.11, 'dissolved_oxygen': 6.11}
# Productor: 0
# Sent: {'timestamp': 1741174750, 'water_temperature': 27.58265814525684, 'ph_level': 8.378182923687719, 'turbidity': 46.42, 'dissolved_oxygen': 5.27}
# Productor: 1
# Sent: {'timestamp': 1741174750, 'water_temperature': 26.435065025849244, 'ph_level': 7.798200307563509, 'turbidity': 28.73, 'dissolved_oxygen': 6.08}
# Productor: 2
# Sent: {'timestamp': 1741174750, 'water_temperature': 26.09309345246594, 'ph_level': 8.342888358431223, 'turbidity': 24.43, 'dissolved_oxygen': 7.08}
# Productor: 0
# Sent: {'timestamp': 1741174751, 'water_temperature': 27.519748676332682, 'ph_level': 7.995337993190343, 'turbidity': 24.35, 'dissolved_oxygen': 8.57}
# Productor: 1
# Sent: {'timestamp': 1741174751, 'water_temperature': 26.92830661903674, 'ph_level': 7.873850527314922, 'turbidity': 27.94, 'dissolved_oxygen': 6.06}
# Productor: 2
# Sent: {'timestamp': 1741174751, 'water_temperature': 27.415772840485, 'ph_level': 7.763598750437145, 'turbidity': 22.73, 'dissolved_oxygen': 9.22}
# Productor: 0
# Sent: {'timestamp': 1741174752, 'water_temperature': 26.335779910534757, 'ph_level': 8.348544973714203, 'turbidity': 29.58, 'dissolved_oxygen': 11.79}
# Productor: 1
# Sent: {'timestamp': 1741174752, 'water_temperature': 26.954336131913266, 'ph_level': 7.678529790948875, 'turbidity': 38.32, 'dissolved_oxygen': 6.6}
# Productor: 2
# Sent: {'timestamp': 1741174752, 'water_temperature': 27.8648530192939, 'ph_level': 8.025325957522258, 'turbidity': 17.82, 'dissolved_oxygen': 9.99}
# Productor: 0
# Sent: {'timestamp': 1741174753, 'water_temperature': 27.512908943780616, 'ph_level': 8.057467143925544, 'turbidity': 27.64, 'dissolved_oxygen': 9.3}
# Productor: 1
# Sent: {'timestamp': 1741174753, 'water_temperature': 26.32996496576984, 'ph_level': 8.46027961612676, 'turbidity': 34.88, 'dissolved_oxygen': 10.44}
# Productor: 2
# Sent: {'timestamp': 1741174753, 'water_temperature': 27.838725603208164, 'ph_level': 8.210013480449229, 'turbidity': 19.43, 'dissolved_oxygen': 10.93}
# Productor: 0
# Sent: {'timestamp': 1741174754, 'water_temperature': 26.386542751672824, 'ph_level': 8.066410466057825, 'turbidity': 33.81, 'dissolved_oxygen': 9.78}
# Productor: 1
# Sent: {'timestamp': 1741174754, 'water_temperature': 26.6753598521629, 'ph_level': 7.858528527623798, 'turbidity': 46.15, 'dissolved_oxygen': 5.16}
# Productor: 2
# Sent: {'timestamp': 1741174754, 'water_temperature': 26.629684813180614, 'ph_level': 7.867685211721864, 'turbidity': 34.79, 'dissolved_oxygen': 9.72}
# Productor: 0
# Sent: {'timestamp': 1741174755, 'water_temperature': 27.441484803621194, 'ph_level': 8.014879314290566, 'turbidity': 48.81, 'dissolved_oxygen': 10.71}
# Productor: 1
# Sent: {'timestamp': 1741174755, 'water_temperature': 26.849385537191615, 'ph_level': 7.637933116341395, 'turbidity': 48.37, 'dissolved_oxygen': 6.97}
# Productor: 2
# Sent: {'timestamp': 1741174755, 'water_temperature': 26.486276299001464, 'ph_level': 7.718551382392052, 'turbidity': 30.17, 'dissolved_oxygen': 11.86}
# Stopped producing messages.

# %% [markdown]
# ## **Ejercicio 2.7**
#
#
# **Enunciado**: Modifica el archivo water_data_consumer_pr_2.ipynb para tener consumidores con un group_id común. Cada sensor_id debe producir un plot con los datos producidos por ese sensor_id. Crea una copia de water_data_consumer_pr_2.ipynb modificado y adjunta captura de los dos notebooks modificados ejecutándose a la vez y gestionando diferentes sensor_id y los plots resultantes.
#
# Si se debe generar un gráfico (plot) por cada sensor, entonces habrá tantos productores como sensores. Supongamos que tenemos 3 sensores; en ese caso, necesitamos implementar 3 productores, los cuales escribirán en un mismo topic, llamado 'water_quality'. Dado que cada consumidor debe procesar los datos de un sensor específico para generar un gráfico, es necesario dividir el topic en 3 particiones. De esta forma, cada consumidor podrá acceder a una partición que esté asociada a un sensor particular.

# %%
from kafka import KafkaProducer
from kafka import KafkaAdminClient
from kafka.admin import NewTopic

import json
import time
import random
from math import cos, pi
import numpy as np

# %%
def generate_sensor_data():
    timestamp = int(time.time())

    # Simulate IoT sensor data for water quality metrics with realistic patterns
    water_temperature = random.uniform(1, 3) + round(20 + 5 * (1 + 0.5 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi))), 2)
    ph_level = random.uniform(0, 1) + round(7.5 + 0.2 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi)), 2)
    turbidity = round(random.uniform(5, 50), 2)  # Turbidity in NTU (Nephelometric Turbidity Units)
    dissolved_oxygen = round(random.uniform(5, 12), 2)  # Dissolved Oxygen in mg/L
    
    return {
        "timestamp": timestamp,
        "water_temperature": water_temperature,
        "ph_level": ph_level,
        "turbidity": turbidity,
        "dissolved_oxygen": dissolved_oxygen
    }

# %%
### CÓDIGO PARA ELIMINAR EL TOPIC Y VOLVER A CREARLO CON "N" PARTICIONES
# admin_client = KafkaAdminClient(bootstrap_servers=kafka_bootstrap_servers)
# existing_topics = admin_client.list_topics()

# if kafka_topic in existing_topics:
#     print(f"El topic '{kafka_topic}' ya existe. Eliminándolo...")
#     admin_client.delete_topics([kafka_topic])
# Out:
# El topic 'water_quality' ya existe. Eliminándolo...

# %%
### Creacion del topic con tantas particiones como sensores existan.
sensors = 2
# Se usa el cliente de Kafka en Python
admin_client = KafkaAdminClient(bootstrap_servers=kafka_bootstrap_servers)
topic = NewTopic(name='water_quality', num_partitions=sensors, replication_factor=1)

admin_client.create_topics([topic])

print(f"Topic '{kafka_topic}' creado con {sensors} particiones.")
# Out:
# Topic 'water_quality' creado con 2 particiones.

# %%
import sys
import time
# Kafka configuration
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

# 2 sensores
producer_number = sensors
producers = []
producer_ids = []

for i in range(producer_number):
    producer_ids.append(str(i))
    # Create Kafka producer
    producer = KafkaProducer(bootstrap_servers=kafka_bootstrap_servers,value_serializer=lambda v: json.dumps(v).encode('utf-8'))
    producers.append(producer)

print(f"Producing messages to Kafka topic '{kafka_topic}'...")

try:
    while True:
        for i in range(producer_number):
            # Generate sensor data
            sensor_data = generate_sensor_data()
            print(f'Sensor: {i} sends data: {sensor_data}')
            # Publish sensor data to Kafka
            producers[i].send(kafka_topic, key=producer_ids[i].encode('utf-8'),value=sensor_data)

        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped producing messages.")
finally:
    for producer in producers:
        producer.close()
