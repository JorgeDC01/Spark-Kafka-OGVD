# %%
from kafka import KafkaConsumer
import json
import matplotlib.pyplot as plt
import time

# %%
# Initialize data storage for plotting
# timestamps = []
# water_temperatures = []
# ph_levels = []
# turbidities = []
# dissolved_oxygen_levels = []

sensor_data_dict = {}

# %%
# Kafka configuration
def initialize_consumer():
    kafka_topic = "water_quality"
    kafka_bootstrap_servers = ["localhost:9092"]

    # Create Kafka consumer
    consumer = KafkaConsumer(
        kafka_topic,
        bootstrap_servers=kafka_bootstrap_servers,
        value_deserializer=lambda m: json.loads(m.decode('utf-8')),
        auto_offset_reset='latest',
        enable_auto_commit=True,
        group_id="water_quality_processors"
    )
    return consumer

# %%
def update_plot(consumer):

    try:
        for message in consumer:
            
            sensor_data = message.value
            
            print(f"Received: {sensor_data}")
            
            sensor_id = sensor_data['sensor_id']  
            print(f"id: {sensor_id}")
            if sensor_id not in sensor_data_dict:
                sensor_data_dict[sensor_id] = {
                    'timestamps': [],
                    'water_temperatures': [],
                    'ph_levels': [],
                    'turbidities': [],
                    'dissolved_oxygen_levels': []
                }

            sensor_data_dict[sensor_id]['timestamps'].append(sensor_data['timestamp'])
            sensor_data_dict[sensor_id]['water_temperatures'].append(sensor_data['water_temperature'])
            sensor_data_dict[sensor_id]['ph_levels'].append(sensor_data['ph_level'])
            sensor_data_dict[sensor_id]['turbidities'].append(sensor_data['turbidity'])
            sensor_data_dict[sensor_id]['dissolved_oxygen_levels'].append(sensor_data['dissolved_oxygen'])

            # Keep only the last 100 entries for plotting
            if len(sensor_data_dict[sensor_id]['timestamps']) > 100:
                sensor_data_dict[sensor_id]['timestamps'].pop(0)
                sensor_data_dict[sensor_id]['water_temperatures'].pop(0)
                sensor_data_dict[sensor_id]['ph_levels'].pop(0)
                sensor_data_dict[sensor_id]['turbidities'].pop(0)
                sensor_data_dict[sensor_id]['dissolved_oxygen_levels'].pop(0)

            data = sensor_data_dict[sensor_id]
        
            timestamps = data['timestamps']
            water_temperatures = data['water_temperatures']
            ph_levels = data['ph_levels']
            turbidities = data['turbidities']
            dissolved_oxygen_levels = data['dissolved_oxygen_levels']


            plt.figure(figsize=(10, 8))

            plt.subplot(2, 2, 1)
            plt.plot(timestamps, water_temperatures, label="Water Temperature", color="blue")
            plt.title(f"Sensor {sensor_id} - Water Temperature")
            plt.ylabel("°C")

            plt.subplot(2, 2, 2)
            plt.plot(timestamps, ph_levels, label="pH Level", color="green")
            plt.title(f"Sensor {sensor_id} - pH Level")
            plt.ylabel("pH")

            plt.subplot(2, 2, 3)
            plt.plot(timestamps, turbidities, label="Turbidity", color="orange")
            plt.title(f"Sensor {sensor_id} - Turbidity")
            plt.ylabel("NTU")

            plt.subplot(2, 2, 4)
            plt.plot(timestamps, dissolved_oxygen_levels, label="Dissolved Oxygen", color="red")
            plt.title(f"Sensor {sensor_id} - Dissolved Oxygen")
            plt.ylabel("mg/L")

            plt.tight_layout()
            # Save the plot as an image
            plt.savefig(f"sensor_{sensor_id}_water_quality_plot.png")
            plt.close()

            break
    except KeyboardInterrupt:
        print("Stopped consuming messages.")
        consumer.close()

# %%
consumer = initialize_consumer()
print("Subscribed to Kafka topic 'water_quality'.")

try:
    while True:
        update_plot(consumer)
except KeyboardInterrupt:
    print("Stopped visualization.")
    consumer.close()
# Out:
# Subscribed to Kafka topic 'water_quality'.
# Received: {'sensor_id': 1, 'timestamp': 1741186007, 'water_temperature': 28.018991117858352, 'ph_level': 7.975691113243694, 'turbidity': 23.65, 'dissolved_oxygen': 9.36}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186007, 'water_temperature': 28.527388280805134, 'ph_level': 8.409207246586742, 'turbidity': 14.94, 'dissolved_oxygen': 6.02}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186007, 'water_temperature': 27.830472030408888, 'ph_level': 7.700855897675119, 'turbidity': 22.57, 'dissolved_oxygen': 5.93}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186008, 'water_temperature': 28.106623574454396, 'ph_level': 8.103899688054376, 'turbidity': 29.1, 'dissolved_oxygen': 6.45}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186008, 'water_temperature': 26.714580326461235, 'ph_level': 7.931821928697381, 'turbidity': 23.14, 'dissolved_oxygen': 10.46}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186008, 'water_temperature': 28.209842179173805, 'ph_level': 8.430064067301323, 'turbidity': 28.1, 'dissolved_oxygen': 8.7}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186009, 'water_temperature': 26.88884824939558, 'ph_level': 7.769870806582154, 'turbidity': 14.27, 'dissolved_oxygen': 5.72}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186009, 'water_temperature': 28.286488228154425, 'ph_level': 8.293282011955508, 'turbidity': 33.22, 'dissolved_oxygen': 10.33}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186009, 'water_temperature': 27.936302242870383, 'ph_level': 8.35078955845794, 'turbidity': 23.15, 'dissolved_oxygen': 7.62}
# id: 4
# Received: {'sensor_id': 4, 'timestamp': 1741186010, 'water_temperature': 26.9514017075942, 'ph_level': 8.368402964216001, 'turbidity': 49.17, 'dissolved_oxygen': 9.06}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186010, 'water_temperature': 26.90990014994594, 'ph_level': 8.409359849051102, 'turbidity': 19.75, 'dissolved_oxygen': 9.85}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186010, 'water_temperature': 27.010649308251537, 'ph_level': 8.387941530848234, 'turbidity': 48.08, 'dissolved_oxygen': 11.06}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186011, 'water_temperature': 28.098042398071826, 'ph_level': 7.671406364603245, 'turbidity': 35.12, 'dissolved_oxygen': 9.12}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186011, 'water_temperature': 26.905133859757097, 'ph_level': 7.714565106354401, 'turbidity': 21.06, 'dissolved_oxygen': 8.48}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186011, 'water_temperature': 27.818322368465903, 'ph_level': 7.9423563823965875, 'turbidity': 47.84, 'dissolved_oxygen': 10.17}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186012, 'water_temperature': 27.911010036793556, 'ph_level': 8.062447008604401, 'turbidity': 21.01, 'dissolved_oxygen': 11.46}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186012, 'water_temperature': 28.499564363769085, 'ph_level': 7.957313234925556, 'turbidity': 13.56, 'dissolved_oxygen': 7.67}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186012, 'water_temperature': 27.523597260153934, 'ph_level': 7.991358569151685, 'turbidity': 9.57, 'dissolved_oxygen': 11.99}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186013, 'water_temperature': 28.271240388345834, 'ph_level': 8.154382648575076, 'turbidity': 6.15, 'dissolved_oxygen': 6.77}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186013, 'water_temperature': 27.641564932202346, 'ph_level': 7.9943377378707705, 'turbidity': 20.52, 'dissolved_oxygen': 5.73}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186013, 'water_temperature': 27.290724860858713, 'ph_level': 8.221401902502206, 'turbidity': 25.11, 'dissolved_oxygen': 6.93}
# id: 4
# Received: {'sensor_id': 4, 'timestamp': 1741186014, 'water_temperature': 27.707892833718482, 'ph_level': 8.513364215549933, 'turbidity': 23.34, 'dissolved_oxygen': 6.61}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186014, 'water_temperature': 27.664609915614875, 'ph_level': 7.8923400474926835, 'turbidity': 18.74, 'dissolved_oxygen': 10.32}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186014, 'water_temperature': 28.04355430853879, 'ph_level': 7.799959443216212, 'turbidity': 47.7, 'dissolved_oxygen': 12.0}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186015, 'water_temperature': 27.51004429064586, 'ph_level': 8.185289509957062, 'turbidity': 49.32, 'dissolved_oxygen': 10.11}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186015, 'water_temperature': 27.70244922896483, 'ph_level': 7.61967484716345, 'turbidity': 33.0, 'dissolved_oxygen': 10.53}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186015, 'water_temperature': 27.235405486495406, 'ph_level': 8.332077514574891, 'turbidity': 15.75, 'dissolved_oxygen': 8.25}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186016, 'water_temperature': 28.455249611476976, 'ph_level': 8.309596859102117, 'turbidity': 43.47, 'dissolved_oxygen': 10.86}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186016, 'water_temperature': 28.4544036006453, 'ph_level': 7.721777692416964, 'turbidity': 38.79, 'dissolved_oxygen': 8.52}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186016, 'water_temperature': 27.209745260013847, 'ph_level': 8.044152388809422, 'turbidity': 8.94, 'dissolved_oxygen': 9.61}
# id: 3
# Received: {'sensor_id': 3, 'timestamp': 1741186017, 'water_temperature': 27.959730615293573, 'ph_level': 7.791285982932109, 'turbidity': 48.6, 'dissolved_oxygen': 5.79}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186017, 'water_temperature': 28.184765836177316, 'ph_level': 7.710115478623663, 'turbidity': 44.45, 'dissolved_oxygen': 9.71}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186017, 'water_temperature': 27.804561003388738, 'ph_level': 8.406552544891017, 'turbidity': 37.09, 'dissolved_oxygen': 9.48}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186018, 'water_temperature': 28.254728306771995, 'ph_level': 8.411570070872248, 'turbidity': 25.0, 'dissolved_oxygen': 11.29}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186018, 'water_temperature': 28.3137872446954, 'ph_level': 7.680556870749699, 'turbidity': 25.19, 'dissolved_oxygen': 10.97}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186018, 'water_temperature': 27.181483194303585, 'ph_level': 8.048639679111384, 'turbidity': 44.45, 'dissolved_oxygen': 6.98}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186019, 'water_temperature': 28.17475977700589, 'ph_level': 7.861721079995096, 'turbidity': 14.72, 'dissolved_oxygen': 11.07}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186019, 'water_temperature': 27.618331397569257, 'ph_level': 8.45872624523532, 'turbidity': 44.54, 'dissolved_oxygen': 6.02}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186019, 'water_temperature': 26.695715360491846, 'ph_level': 8.336733862487215, 'turbidity': 6.98, 'dissolved_oxygen': 5.55}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186020, 'water_temperature': 27.12830117857418, 'ph_level': 7.659477305402654, 'turbidity': 43.58, 'dissolved_oxygen': 9.22}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186020, 'water_temperature': 27.56141398266972, 'ph_level': 7.747830863358143, 'turbidity': 10.45, 'dissolved_oxygen': 10.35}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186020, 'water_temperature': 27.298486344861715, 'ph_level': 8.09560895098868, 'turbidity': 18.89, 'dissolved_oxygen': 10.61}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186021, 'water_temperature': 27.027326068425364, 'ph_level': 7.571358341673518, 'turbidity': 18.37, 'dissolved_oxygen': 7.66}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186021, 'water_temperature': 28.052835472179602, 'ph_level': 8.046246142379037, 'turbidity': 20.54, 'dissolved_oxygen': 11.04}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186021, 'water_temperature': 27.167142165120037, 'ph_level': 7.973134906313845, 'turbidity': 25.16, 'dissolved_oxygen': 5.17}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186022, 'water_temperature': 27.91290485837486, 'ph_level': 8.373817296397975, 'turbidity': 13.63, 'dissolved_oxygen': 7.72}
# id: 1
# Received: {'sensor_id': 3, 'timestamp': 1741186022, 'water_temperature': 27.43595152643423, 'ph_level': 7.660801596268995, 'turbidity': 26.85, 'dissolved_oxygen': 7.24}
# id: 3
# Received: {'sensor_id': 4, 'timestamp': 1741186022, 'water_temperature': 28.056829182066316, 'ph_level': 7.986219924310737, 'turbidity': 30.64, 'dissolved_oxygen': 9.47}
# id: 4
# Received: {'sensor_id': 3, 'timestamp': 1741186023, 'water_temperature': 27.172922484629154, 'ph_level': 7.6365515194652875, 'turbidity': 40.02, 'dissolved_oxygen': 5.78}
# id: 3
# Received: {'sensor_id': 1, 'timestamp': 1741186023, 'water_temperature': 28.60080870757987, 'ph_level': 7.786885228031327, 'turbidity': 13.16, 'dissolved_oxygen': 6.22}
# id: 1
# Received: {'sensor_id': 4, 'timestamp': 1741186023, 'water_temperature': 27.971301223535736, 'ph_level': 8.438782400385938, 'turbidity': 46.98, 'dissolved_oxygen': 7.95}
# id: 4
# Received: {'sensor_id': 1, 'timestamp': 1741186024, 'water_temperature': 27.349242382471353, 'ph_level': 7.943246195233345, 'turbidity': 7.98, 'dissolved_oxygen': 7.89}
# id: 1
# Stopped consuming messages.
# Stopped visualization.
