# %% [markdown]
# ## **Ejercicio 2.7**
#
#
# **Enunciado**: Modifica el archivo water_data_consumer_pr_2.ipynb para tener consumidores con un group_id común. Cada sensor_id debe producir un plot con los datos producidos por ese sensor_id. Crea una copia de water_data_consumer_pr_2.ipynb modificado y adjunta captura de los dos notebooks modificados ejecutándose a la vez y gestionando diferentes sensor_id y los plots resultantes.
#
# Si se debe generar un gráfico (plot) por cada sensor, entonces habrá tantos productores como sensores. Supongamos que tenemos 6 sensores; en ese caso, necesitamos implementar 6 productores, los cuales escribirán en un mismo topic, llamado 'water_quality'. Se divide el topic en 2 particiones

# %%
from kafka import KafkaProducer
from kafka import KafkaAdminClient
from kafka.admin import NewTopic

import json
import time
import random
from math import cos, pi
import numpy as np

# %%
def generate_sensor_data(sensor_id):
    timestamp = int(time.time())

    # Simulate IoT sensor data for water quality metrics with realistic patterns
    water_temperature = random.uniform(1, 3) + round(20 + 5 * (1 + 0.5 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi))), 2)
    ph_level = random.uniform(0, 1) + round(7.5 + 0.2 * (1 + cos((timestamp % 86400) / 86400 * 2 * pi)), 2)
    turbidity = round(random.uniform(5, 50), 2)  # Turbidity in NTU (Nephelometric Turbidity Units)
    dissolved_oxygen = round(random.uniform(5, 12), 2)  # Dissolved Oxygen in mg/L
    
    return {
        "sensor_id": sensor_id,
        "timestamp": timestamp,
        "water_temperature": water_temperature,
        "ph_level": ph_level,
        "turbidity": turbidity,
        "dissolved_oxygen": dissolved_oxygen
    }

# %%
### CÓDIGO PARA ELIMINAR EL TOPIC Y VOLVER A CREARLO CON "N" PARTICIONES
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

admin_client = KafkaAdminClient(bootstrap_servers=kafka_bootstrap_servers)
existing_topics = admin_client.list_topics()

if kafka_topic in existing_topics:
    print(f"El topic '{kafka_topic}' ya existe. Eliminándolo...")
    admin_client.delete_topics([kafka_topic])

# %%
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

### Creacion del topic con tantas particiones como sensores existan.
partitions = 2
# Se usa el cliente de Kafka en Python
admin_client = KafkaAdminClient(bootstrap_servers=kafka_bootstrap_servers)
topic = NewTopic(name='water_quality', num_partitions=partitions, replication_factor=1)

admin_client.create_topics([topic])

print(f"Topic '{kafka_topic}' creado con {partitions} particiones.")
# Out:
# Topic 'water_quality' creado con 2 particiones.

# %%
import sys
import time
# Kafka configuration
kafka_topic = "water_quality"
kafka_bootstrap_servers = ["localhost:9092"] 

# 6 sensores
producer_number = 6
producers = []
producer_ids = []

for i in range(producer_number):
    producer_ids.append(str(i))
    # Create Kafka producer
    producer = KafkaProducer(bootstrap_servers=kafka_bootstrap_servers,value_serializer=lambda v: json.dumps(v).encode('utf-8'))
    producers.append(producer)

print(f"Producing messages to Kafka topic '{kafka_topic}'...")

try:
    while True:
        for i in range(producer_number):
            # Generate sensor data
            sensor_data = generate_sensor_data(i)
            print(f'Sensor: {i} sends data: {sensor_data}')
            # Publish sensor data to Kafka
            print(f"keyyy: {producer_ids[i].encode('utf-8')}")
            producers[i].send(kafka_topic, key=producer_ids[i].encode('utf-8'),value=sensor_data)

        time.sleep(1)
except KeyboardInterrupt:
    print("Stopped producing messages.")
finally:
    for producer in producers:
        producer.close()
# Out:
# Producing messages to Kafka topic 'water_quality'...
# Sensor: 0 sends data: {'sensor_id': 0, 'timestamp': 1741

# keyyy: b'4'
# Sensor: 5 sends data: {'sensor_id': 5, 'timestamp': 1741186049, 'water_temperature': 27.811480484666372, 'ph_level': 8.211659231361445, 'turbidity': 41.79, 'dissolved_oxygen': 8.2}
# keyyy: b'5'
# Sensor: 0 sends data: {'sensor_id': 0, 'timestamp': 1741186050, 'water_temperature': 27.248789501962435, 'ph_level': 7.937701746945428, 'turbidity': 26.64, 'dissolved_oxygen': 10.23}
# keyyy: b'0'
# Sensor: 1 sends data: {'sensor_id': 1, 'timestamp': 1741186050, 'water_temperature': 27.16495034274281, 'ph_level': 7.740211852526871, 'turbidity': 44.93, 'dissolved_oxygen': 11.39}
# keyyy: b'1'
# Sensor: 2 sends data: {'sensor_id': 2, 'timestamp': 1741186050, 'water_temperature': 27.846899007862014, 'ph_level': 7.736212304690872, 'turbidity': 6.76, 'dissolved_oxygen': 7.49}
# keyyy: b'2'
# Sensor: 3 sends data: {'sensor_id': 3, 'timestamp': 1741186050, 'water_temperature': 27.829816101254703, 'ph_level': 8.118026130630092, 'turbidity': 10.16, 'dissolved_oxygen': 9.14}
# keyyy: b'3'
# Sensor: 4 sends data: {'sensor_id': 4, 'timestamp': 1741186050, 'water_temperature': 26.690066966753005, 'ph_level': 7.59472729037102, 'turbidity': 41.29, 'dissolved_oxygen': 10.41}
# keyyy: b'4'
# Sensor: 5 sends data: {'sensor_id': 5, 'timestamp': 1741186050, 'water_temperature': 28.59774386404721, 'ph_level': 7.951144893571839, 'turbidity': 12.59, 'dissolved_oxygen': 9.4}
# keyyy: b'5'
# Sensor: 0 sends data: {'sensor_id': 0, 'timestamp': 1741186051, 'water_temperature': 27.86465519119736, 'ph_level': 8.535949227243737, 'turbidity': 27.21, 'dissolved_oxygen': 8.4}
# keyyy: b'0'
# Sensor: 1 sends data: {'sensor_id': 1, 'timestamp': 1741186051, 'water_temperature': 26.978122396000746, 'ph_level': 8.230997356196054, 'turbidity': 23.69, 'dissolved_oxygen': 9.87}
# keyyy: b'1'
# Sensor: 2 sends data: {'sensor_id': 2, 'timestamp': 1741186051, 'water_temperature': 28.40315552393851, 'ph_level': 7.896858884928305, 'turbidity': 29.26, 'dissolved_oxygen': 9.92}
# keyyy: b'2'
# Sensor: 3 sends data: {'sensor_id': 3, 'timestamp': 1741186051, 'water_temperature': 27.78747214769986, 'ph_level': 8.333745954762893, 'turbidity': 43.63, 'dissolved_oxygen': 8.92}
# keyyy: b'3'
# Sensor: 4 sends data: {'sensor_id': 4, 'timestamp': 1741186051, 'water_temperature': 28.624551548415752, 'ph_level': 8.184839931816473, 'turbidity': 32.48, 'dissolved_oxygen': 9.1}
# keyyy: b'4'
# Sensor: 5 sends data: {'sensor_id': 5, 'timestamp': 1741186051, 'water_temperature': 27.319105632617582, 'ph_level': 8.291823460193045, 'turbidity': 49.97, 'dissolved_oxygen': 7.22}
# keyyy: b'5'
# Sensor: 0 sends data: {'sensor_id': 0, 'timestamp': 1741186052, 'water_temperature': 28.410412018025873, 'ph_level': 8.311401779428525, 'turbidity': 21.85, 'dissolved_oxygen': 6.11}
# keyyy: b'0'
# Sensor: 1 sends data: {'sensor_id': 1, 'timestamp': 1741186052, 'water_temperature': 28.57996393704027, 'ph_level': 8.5349804199076, 'turbidity': 20.06, 'dissolved_oxygen': 5.41}
# keyyy: b'1'
# Sensor: 2 sends data: {'sensor_id': 2, 'timestamp': 1741186052, 'water_temperature': 28.35978477792527, 'ph_level': 7.799640972585614, 'turbidity': 11.53, 'dissolved_oxygen': 11.67}
# keyyy: b'2'
# Sensor: 3 sends data: {'sensor_id': 3, 'timestamp': 1741186052, 'water_temperature': 27.706779441069095, 'ph_level': 8.454801383792377, 'turbidity': 7.38, 'dissolved_oxygen': 6.03}
# keyyy: b'3'
# Sensor: 4 sends data: {'sensor_id': 4, 'timestamp': 1741186052, 'water_temperature': 26.95794866672394, 'ph_level': 7.629867488474322, 'turbidity': 25.75, 'dissolved_oxygen': 8.0}
# keyyy: b'4'
# Sensor: 5 sends data: {'sensor_id': 5, 'timestamp': 1741186052, 'water_temperature': 28.53226124274736, 'ph_level': 7.866302550050074, 'turbidity': 37.58, 'dissolved_oxygen': 9.96}
# keyyy: b'5'
# Stopped producing messages.
